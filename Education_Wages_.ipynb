# %% [markdown]
# ------------------
# ## **<u> Wages by Education </u>**
# - Author(s): Dylan Benson and Sam Coronado Cepeda (Group 6)

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv(r"C:\Users\dylan\DTSC 1302\wages_by_education.csv")
df.head(10)
# Out:
#    year  less_than_hs  high_school  some_college  bachelors_degree  \
# 0  2022         16.52        21.94         24.81             41.60
# 1  2021         16.74        22.28         24.92             41.32
# 2  2020         17.02        22.70         25.44             41.65
# 3  2019         16.11        21.64         24.00             39.61
# 4  2018         15.94        21.50         23.70             38.87
# 5  2017         15.92        21.26         23.31             38.65
# 6  2016         15.45        21.00         23.35             38.73
# 7  2015         15.25        20.81         23.17             37.96
# 8  2014         14.66        20.34         22.48             36.47
# 9  2013         14.62        20.31         22.50             37.00
#
#    advanced_degree  men_less_than_hs  men_high_school  men_some_college  \
# 0            53.22             17.99            24.08             27.96
# 1            53.45             18.34            24.36             27.96
# ...

# %%
list(df.columns.values)
# Out:
# ['year',
#  'less_than_hs',
#  'high_school',
#  'some_college',
#  'bachelors_degree',
#  'advanced_degree',
#  'men_less_than_hs',
#  'men_high_school',
#  'men_some_college',
#  'men_bachelors_degree',
#  'men_advanced_degree',
#  'women_less_than_hs',
#  'women_high_school',
#  'women_some_college',
#  'women_bachelors_degree',
#  'women_advanced_degree',
#  'white_less_than_hs',
#  'white_high_school',
#  'white_some_college',
#  'white_bachelors_degree',
#  'white_advanced_degree',
#  'black_less_than_hs',
#  'black_high_school',
#  'black_some_college',
#  'black_bachelors_degree',
#  'black_advanced_degree',
#  'hispanic_less_than_hs',
#  'hispanic_high_school',
#  'hispanic_some_college',
#  'hispanic_bachelors_degree',
#  'hispanic_advanced_degree',
#  'white_men_less_than_hs',
#  'white_men_high_school',
#  'white_men_some_college',
#  'white_men_bachelors_degree',
#  'white_men_advanced_degree',
#  'black_men_less_than_hs',
#  'black_men_high_school',
# ...

# %%
# Percent missing values by variable
df.isna().sum()/len(df)*100
# Out:
# year                               0.0
# less_than_hs                       0.0
# high_school                        0.0
# some_college                       0.0
# bachelors_degree                   0.0
#                                   ...
# hispanic_women_less_than_hs        0.0
# hispanic_women_high_school         0.0
# hispanic_women_some_college        0.0
# hispanic_women_bachelors_degree    0.0
# hispanic_women_advanced_degree     0.0
# Length: 61, dtype: float64

# %% [markdown]
# ## **Summary Statistics**
# --------------------------

# %% [markdown]
# - Mean, Median, Mode, Standard Deviation, and Interquartile Range for Bachelor's Degree

# %%
import numpy as np
from scipy.stats import mode
from scipy.stats import iqr


# Sample data
data = df['bachelors_degree']

# Calculating mean, median, mode, standard deviation, and interquartile range
mean_value = np.mean(data)
median_value = np.median(data)
mode_value = mode(data, keepdims = False)
std_deviation = np.std(data, ddof=1)  # Using ddof=1 for sample standard deviation
interquartile_range = iqr(data)

print("Mean:", mean_value)
print("Median:", median_value)
print("Mode:", mode_value.mode)
print("Standard Deviation:", std_deviation)
print("Interquartile Range:", interquartile_range)
# Out:
# Mean: 34.7686
# Median: 34.205
# Mode: 31.07
# Standard Deviation: 3.306645139961748
# Interquartile Range: 5.247500000000002

# %% [markdown]
# - Mean, Median, Mode, Standard Deviation, and Interquartile Range for White People with Bachelor's Degree

# %%
# Sample data
data = df['white_bachelors_degree']

# Calculating mean, median, mode, standard deviation, and interquartile range
mean_value = np.mean(data)
median_value = np.median(data)
mode_value = mode(data, keepdims = False)
std_deviation = np.std(data, ddof=1)  # Using ddof=1 for sample standard deviation
interquartile_range = iqr(data)

print("Mean:", mean_value)
print("Median:", median_value)
print("Mode:", mode_value.mode)
print("Standard Deviation:", std_deviation)
print("Interquartile Range:", interquartile_range)
# Out:
# Mean: 35.651399999999995
# Median: 35.07
# Mode: 30.44
# Standard Deviation: 3.678861297871882
# Interquartile Range: 5.782499999999999

# %% [markdown]
# - Mean, Median, Mode, Standard Deviation, and Interquartile Range for Black People with Bachelor's Degree

# %%
# Sample data
data = df['black_bachelors_degree']

# Calculating mean, median, mode, standard deviation, and interquartile range
mean_value = np.mean(data)
median_value = np.median(data)
mode_value = mode(data, keepdims = False)
std_deviation = np.std(data, ddof=1)  # Using ddof=1 for sample standard deviation
interquartile_range = iqr(data)

print("Mean:", mean_value)
print("Median:", median_value)
print("Mode:", mode_value.mode)
print("Standard Deviation:", std_deviation)
print("Interquartile Range:", interquartile_range)
# Out:
# Mean: 29.571199999999997
# Median: 29.634999999999998
# Mode: 31.42
# Standard Deviation: 2.2738600104093427
# Interquartile Range: 3.965

# %% [markdown]
# - Mean, Median, Mode, Standard Deviation, and Interquartile Range for Hispanic People with Bachelor's Degree

# %%
# Sample data
data = df['hispanic_bachelors_degree']

# Calculating mean, median, mode, standard deviation, and interquartile range
mean_value = np.mean(data)
median_value = np.median(data)
mode_value = mode(data, keepdims = False)
std_deviation = np.std(data, ddof=1)  # Using ddof=1 for sample standard deviation
interquartile_range = iqr(data)

print("Mean:", mean_value)
print("Median:", median_value)
print("Mode:", mode_value.mode)
print("Standard Deviation:", std_deviation)
print("Interquartile Range:", interquartile_range)
# Out:
# Mean: 30.403399999999998
# Median: 30.38
# Mode: 31.28
# Standard Deviation: 2.80556852254474
# Interquartile Range: 3.9499999999999957

# %% [markdown]
# ## **OLS Regression Results / Models**
# --------------------------

# %%
independent_vars = ['white_less_than_hs', 'white_high_school', 'white_some_college', 'white_bachelors_degree', 'white_advanced_degree',
                     'black_less_than_hs', 'black_high_school', 'black_some_college', 'black_bachelors_degree', 'black_advanced_degree',
                     'hispanic_less_than_hs', 'hispanic_high_school', 'hispanic_some_college', 'hispanic_bachelors_degree', 'hispanic_advanced_degree']

dependent_var = 'some_college'

X = df[independent_vars]

X = sm.add_constant(X)

model = sm.OLS(df[dependent_var], X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           some_college   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     620.7
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           6.36e-37
# Time:                        17:05:31   Log-Likelihood:                 82.615
# No. Observations:                  50   AIC:                            -133.2
# Df Residuals:                      34   BIC:                            -102.6
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        -0.7462      0.509     -1.465      0.152      -1.781       0.289
# ...

# %%
residuals = model.resid
plt.scatter(df[dependent_var], residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
independent_vars = ['hispanic_bachelors_degree']

dependent_var = 'bachelors_degree'

X = df[independent_vars]

X = sm.add_constant(X)

model = sm.OLS(df[dependent_var], X).fit()


print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       bachelors_degree   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     413.2
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           3.15e-25
# Time:                        17:05:31   Log-Likelihood:                -73.673
# No. Observations:                  50   AIC:                             151.3
# Df Residuals:                      48   BIC:                             155.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.8511      1.676      0.508      0.614      -2.518       4.220
# ...

# %%
residuals = model.resid
plt.scatter(df[dependent_var], residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
independent_vars = ['white_bachelors_degree']

dependent_var = 'bachelors_degree'

X = df[independent_vars]

X = sm.add_constant(X)

model = sm.OLS(df[dependent_var], X).fit()


print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       bachelors_degree   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 5.453e+04
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           5.25e-75
# Time:                        17:05:31   Log-Likelihood:                 45.668
# No. Observations:                  50   AIC:                            -87.34
# Df Residuals:                      48   BIC:                            -83.51
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      2.7384      0.138     19.862      0.000       2.461       3.016
# ...

# %%
residuals = model.resid
plt.scatter(df[dependent_var], residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
independent_vars = ['black_bachelors_degree']

dependent_var = 'bachelors_degree'

X = df[independent_vars]

X = sm.add_constant(X)

model = sm.OLS(df[dependent_var], X).fit()


print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       bachelors_degree   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     555.9
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           4.82e-28
# Time:                        17:05:31   Log-Likelihood:                -66.933
# No. Observations:                  50   AIC:                             137.9
# Df Residuals:                      48   BIC:                             141.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -6.4895      1.755     -3.698      0.001     -10.018      -2.961
# ...

# %%
residuals = model.resid
plt.scatter(df[dependent_var], residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %% [markdown]
# --------------------------
# **Heatmap:** Coorelation between Bachelors Degree Earnings within each Demographic

# %%
df1=df[df['year']>1999]
#print(df1)
df2 = pd.DataFrame()
df2['black_bachelors_degree']=df['black_bachelors_degree']
df2['white_bachelors_degree']=df['white_bachelors_degree']
df2['hispanic_bachelors_degree']=df['hispanic_bachelors_degree']
df2['bachelors_degree']=df['bachelors_degree']

data_corr = df2.copy()
correlation = data_corr.corr()
sb.heatmap(correlation,fmt='.2f', cmap = 'coolwarm',vmin=-1,vmax=1)
plt.show()
print(correlation)
# Out:
#                            black_bachelors_degree  white_bachelors_degree  \
# black_bachelors_degree                   1.000000                0.954148
# white_bachelors_degree                   0.954148                1.000000
# hispanic_bachelors_degree                0.881853                0.946959
# bachelors_degree                         0.959437                0.999560
#
#                            hispanic_bachelors_degree  bachelors_degree
# black_bachelors_degree                      0.881853          0.959437
# white_bachelors_degree                      0.946959          0.999560
# hispanic_bachelors_degree                   1.000000          0.946532
# bachelors_degree                            0.946532          1.000000

# %% [markdown]
# - This heatmap above displays direct coorelation between the wages of each demographic (White, Black, and Hispanic). There is high coorelation among the overall wage distribution.

# %% [markdown]
# --------------------------
# **Bar Plots:** Bachelors Degree Earnings per Demographic

# %%
df2['year']=df1['year']
plt.bar(df2['year'],df2['white_bachelors_degree'])
plt.title('Avg. Wage: White people with Bachelors Degree')
plt.xlabel('Year')
plt.ylabel('Hourly Wage')
plt.show()

# %%
df2['year']=df1['year']
plt.bar(df2['year'],df2['black_bachelors_degree'])
plt.title('Avg. Wage: Black people with Bachelors Degree')
plt.xlabel('Year')
plt.ylabel('Hourly Wage')
plt.show()

# %%
df2['year']=df1['year']
plt.bar(df2['year'],df2['hispanic_bachelors_degree'])
plt.title('Avg. Hourly wage of Hispanic people with Bachelors Degree')
plt.xlabel('Year')
plt.ylabel('Wage')
plt.show()

# %% [markdown]
# --------------------------
# **Linear Regression Models:** Bachelors Degree Earnings per Demographic

# %%
sb.regplot(x="year", y="black_bachelors_degree", data=df1)
# Out:
# <Axes: xlabel='year', ylabel='black_bachelors_degree'>

# %%
sb.regplot(x="year", y="hispanic_bachelors_degree", data=df1)
# Out:
# <Axes: xlabel='year', ylabel='hispanic_bachelors_degree'>

# %%
sb.regplot(x="year", y="white_bachelors_degree", data=df1)
# Out:
# <Axes: xlabel='year', ylabel='white_bachelors_degree'>

# %% [markdown]
# --------------------------
# **Box Plot:** Bachelors Degree Earnings per Demographic

# %%
columns_of_interest = ['bachelors_degree', 'white_bachelors_degree', 'hispanic_bachelors_degree', 'black_bachelors_degree']
data_for_plot = df[columns_of_interest].melt(var_name='Group', value_name='Earnings')
# Define the color for each group
color_palette = {
    "bachelors_degree": "blue", 
    "white_bachelors_degree": "green", "hispanic_bachelors_degree": "orange", "black_bachelors_degree": "red"      
}

# Create the boxplot with the specified color palette
plt.figure(figsize=(10, 6))
sb.boxplot(x='Group', y='Earnings', data=data_for_plot, palette = color_palette)
plt.title('Box Plot: Earnings for Ethnic Groups with Bachelors Degree')
plt.xlabel('Ethnic Group')
plt.ylabel('Hourly Wage')
plt.show()

# %% [markdown]
# --------------------------
# **Line Graph:** Average Wages Over Years (2000-2022) by Demographic

# %%
demographic_columns = ['year', 'bachelors_degree','white_bachelors_degree', 'black_bachelors_degree', 'hispanic_bachelors_degree']
df_filtered = df[df['year'].between(2000, 2022)][demographic_columns]

color_palette = {
    "bachelors_degree": "blue", 
    "white_bachelors_degree": "green", "hispanic_bachelors_degree": "orange", "black_bachelors_degree": "red"      
}

# Melting the DataFrame for easier plotting with seaborn
df_melted = df_filtered.melt(id_vars='year', var_name='Demographic', value_name='AverageWage')

# Generate the line graph
plt.figure(figsize=(12, 8))
sb.lineplot(data=df_melted, x='year', y='AverageWage', hue='Demographic', palette = color_palette)
plt.title('Line Graph: Average Wages Over Years (2000-2022) by Demographic')
plt.xlabel('Year')
plt.ylabel('Average Wage')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# --------------
# **Bar Chart:** Average Wages Over Years (2000-2022) by Demographic

# %%
# Select relevant columns for the bar chart (bachelor's degree holders among different demographics)
bar_chart_columns = ['year', 'white_bachelors_degree', 'hispanic_bachelors_degree', 'black_bachelors_degree']
bar_chart_df = df[df['year'].between(2000, 2022)][bar_chart_columns]

# Reshaping the data for the bar chart
bar_chart_data = bar_chart_df.melt(id_vars='year', var_name='Demographic', value_name='AverageWage')

green_palette = sb.color_palette("Greens", n_colors=3)

# Generating the Bar Chart
plt.figure(figsize=(12, 8))
sb.barplot(data=bar_chart_data, x='year', y='AverageWage', hue='Demographic', palette = green_palette)
plt.title('Bar Chart: Average Wages Over Years (2000-2022) by Demographic')
plt.xticks(rotation=45)
plt.xlabel('Year')
plt.ylabel('Average Wage')
plt.show()

# %% [markdown]
# ------------------------------
